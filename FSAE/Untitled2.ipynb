# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10,10,1000)
y = np.sin(x)
y2 = np.sin(x**1.4)

plt.figure
plt.plot(x,y2)
plt.show()
# Out:
# <ipython-input-12-946da1deadf2>:6: RuntimeWarning: invalid value encountered in power
#   y2 = np.sin(x**1.4)
