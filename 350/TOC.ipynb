# %% [markdown]
# HW1: vectors and solving systems
# > files (class notes 0830 0901, norms)
#
# HW2: plotting 2d and grid 3d, minimzation and roots, taylor series
# > files (class notes 0908 0915 0920-22, cubic)
#
# Midterm 1: vectors, systems, roots, min, taylor
#
# HW3: curve fitting, file import
# > files (curve_fit)
#
# HW4: eigenvalues/vectors
# > files (eigen)
#
# Midterm 2: eigenvalues, curve fit
#
# HW5: fourier series, audio analysis
# > files (fourier, fourier stepfunc, fourier-fft, fft audio)
#
# HW6: solving ODEs, IVP
# > files (integration, copy of integration)
