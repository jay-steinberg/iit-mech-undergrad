# %%
import numpy as np

a = np.array([[6,-2],[11.5,-3.85]]) #change from -3.85 to -3.84, changes solution massively
print(a)

#because it has a weird norm

print(np.linalg.norm(a)*np.linalg.norm(np.linalg.inv(a))) # ||a|| x ||a^-1|| = condition number of a matrix

# b = np.array([[10, 17]]).T
# print(b)

# x = np.linalg.inv(a)@b

# print("solution: \n", x)
# Out:
# [[ 6.   -2.  ]
#  [11.5  -3.85]]
# 1870.7250000000106
