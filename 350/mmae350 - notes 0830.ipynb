# %%
""" colab is an online version of jupyter notebook """

import numpy as np
import scipy as sc

# %%
# #V=2i+3j-7k

# V=np.array([[2,3,-7]])
# print('V:\n',V)
# print(np.shape(V), "this is the size, rows by columns", '\n')

# Vcol=np.array([[2],[3],[-7]])
# print(Vcol)
# print(np.shape(Vcol), "this is rows by cols", '\n')

# print('length of V hard coded coeffs')
# print(np.sqrt(2**2+3**2+(-7)**2))  #this is the length of v but hardcoded numbers

# print('\nlength of V called individually')
# print(np.sqrt(V[0,0]**2 + V[0,1]**2 + V[0,2]**2)) #call individual vector components by row,column

# print('\nlength of V using norm')
# print(np.linalg.norm(V))

# print(V+V)
# print(V-V)

# bulk select and use ctrl + / to comment large groups

# A=np.array([[2,3,-7]])
# B=np.array([[4,-5,2]])
# C=np.transpose(A)
# print(A)
# print(C)
# print(np.transpose(C))

A=np.array([2,3,-7])   # single brackets are actual vector datatype with only 1-dim
B=np.array([4,-5,2])

print(np.shape(A)) #output shows (3,) because dim2 not defined
print(np.dot(A,B))

# to use dot product properly on matrices, must transpose 1 of them ( A * B^t)

A=np.array([[2,3,-7]])
B=np.array([[4,-5,2]])
C=np.transpose(B)
print(A@C)

A=np.array([2,3,-7])   
B=np.array([4,-5,2])
print(np.shape(A)) 
print(np.dot(A,A))
print(np.linalg.norm(A)**2)
print(A@A)
print(np.arccos(np.dot(A,B)/(np.linalg.norm(A)*np.linalg.norm(B))))  # this should give theta btw vecs in radians
# Out:
# (3,)
# -21
# [[-21]]
# (3,)
# 62
# 62.0
# 62
# 1.9796669336036643
