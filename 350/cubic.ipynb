# %%
import numpy as np
import scipy.optimize as op
import matplotlib.pyplot as plt

def func(z):
  x = z
  return 32.2*x**3 - 146.6*x**2 + 50

x0 = np.linspace(-2,5,50)
plt.plot(x0, func(x0), x0, x0*0)
plt.grid(True)
plt.show()

zGuess = np.array([-20])
op.root(func, [-1,1,5])
# Out:
#     fjac: array([[-0.94602962,  0.30640139,  0.10557527],
#        [-0.30367628, -0.95187599,  0.04138626],
#        [-0.11317537, -0.00709192, -0.99354972]])
#      fun: array([5.00349273e-08, 3.23770479e-07, 6.82844075e-08])
#  message: 'The solution converged.'
#     nfev: 14
#      qtf: array([ 1.80135127e-06, -9.06796574e-06, -2.09943504e-06])
#        r: array([-168.71242104,  -56.48644021, -181.70268018,  149.23084271,
#          -3.56228165, -713.24284961])
#   status: 1
#  success: True
#        x: array([-0.55155261,  0.62908387,  4.47526377])
